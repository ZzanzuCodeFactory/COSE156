# %% [markdown]
# ### 1. mutable/immutable, sequence, iterable의 개념을 정리하시오. (5점)
# 용어집(https://docs.python.org/ko/3/glossary.html)에 있는 내용을 참고하고, 수업 시간에 한 내용을 중심으로
#
# ### 2. 수업 시간에 배운 다양한 type을 다음 표(아래로 계속)로 만들어서 정리하시오. (5점)

# %% [markdown]
# | type | mutable | sequence | iterable |
# |------|------|------|------|
# | int | X | X | X |
# | float | X | X | X |
# | complex | X | X | X |
# | bool | X | X | X |
# | str | O | O | O |
# | byte | X | O | X |
# | bytesarray | O | O | X |
# | list | O | O | O |
# | dict | O | X | O |
# | tuple | X | O | O |
# | set | X | X | O |
# | frozenset | X | X | O |

# %% [markdown]
# ### 3. 다음을 노트북에서 직접 코드를 입력하고 확인하시오. (5점)
# - 3.2 https://docs.python.org/ko/3/tutorial/introduction.html : 다중대입, while,
# - 4.1 / 4.2 / 4.3 / 4.4 / 4.5 https://docs.python.org/ko/3/tutorial/controlflow.html : 파이썬의 for문은 임의의 시퀀스의 항목들을 그 시퀀스에 들어있는 순서대로 이터레이션합니다
# - 5 https://docs.python.org/ko/3/tutorial/datastructures.html

# %% [markdown]
# ### 4. 블랙보드 강의자료 PEP8 참고자료와 4.8 https://docs.python.org/ko/3/tutorial/controlflow.html#intermezzo-coding-style 를 읽어보세요.
# - 네

# %% [markdown]
# ### 5. 다음의 코드를 개선하시오 (5점)

# %% [markdown]
# #### 5-1
# ```python
#     if a < b:
#         if c < 5:
#             print("hello")
# ```

# %%
a = 2
b = 4
c = 1

if a < b and c < 5 :
    print("hello")

# %% [markdown]
# #### 5-2
# ```python
#     if (name == "John") or (name == "George") or \
#         (name == "Paul") or (name == "Ringo"):
#         flag = True
#     else:
#         flag = False
# ```

# %%
name_list = ['John', 'George', 'Paul', 'Ringo']
name = 'Paul'

if name in name_list :
    flag = True
else :
    flag = False

# %% [markdown]
# ### 6. What is wrong with the following program?  (5점)
# ```python
#     initial_val = 10
#     while initial_val >0:
#        print(initial_val)
#        if initial_val == 5:
#            break
#        print(initial_val)
# ```

# %% [markdown]
# answer) 무한 루프 발생, initial_val의 값을 변화시키는 로직 필요

# %% [markdown]
# ### 7. About range()  (5점)

# %% [markdown]
# #### 7-1. What sequence is generated by the function range(5)?
# ##### range(5) = range(a,b) = range(c,d,e) : a,b,c,d,e?
#
# #### 7-2. Why won’t the following lines of code work as intended? range(15,1)를 2가지 방법으로 변경하시오ㅁ
# ```python
# for i in range(15, 1):
#     print(i)
# ```

# %% [markdown]
# 7-1) range(5) = range(0,5) = range(0,5,1) = 0,1,2,3,4

# %% [markdown]
# 7-2)

# %%
# 방법 1
for i in range(0, 15, 1) :
    print(i)

# %%
# 방법 2
for i in range(15) :
    print(i)

# %% [markdown]
# ### 8. Simplify the following code (use for)  (5점)
# #### 8.1
# ```python
# musketeers = ["Athos", "Porthos", "Aramis", "D'Artagnan"]
# i = 0
# while i < len(musketeers):
#         print(musketeers[i])
#         i += 1
# ```
# #### 8.2
# ```python
# (x > 10) and (x <= 20)
# ```
# #### 8.3
# ````python
# not(10 < x <= 20) # not이 없는 표현으로
# ```

# %%
# 8.1
musketeers = ["Athos", "Porthos", "Aramis", "D'Artagnan"] 

for i in musketeers :
    print(i)

# %%
# 8.2
10 < x <= 20

# %%
# 8.3
x <= 10 or x > 20

# %% [markdown]
# ### 9. What is the output of the following lines of code?  (5점)
# ```python
# n = 7
# for i in range(n):
#     print(i, end=" ")
#     n = 3
# ```

# %% [markdown]
# answer) 0 1 2 3 4 5 6

# %%
n = 7
for i in range(n):
    print(i, end=" ")
    n = 3
# Out:
# 0 1 2 3 4 5 6

# %% [markdown]
# ### 10. Write a program that reads an integer from the user. Then your program should display a message indicating whether the integer is even or odd. (5점)

# %%
userInput = int(input("Enter any number : "))

if userInput%2 is 0 :
    print("even")
else :
    print("odd")
# Out:
# Enter any number : 4
# even

# %% [markdown]
# ### 11. 중첩된(nested) for를 사용하여 구구단을 출력하는 코드를 작성하시오. (5점)

# %%
for dan in range(2,10) :
    print(dan,"단")
    for i in range(1, 10) :
        print(dan, 'X', i, "=", dan*i)
# Out:
# 2 단
# 2 X 1 = 2
# 2 X 2 = 4
# 2 X 3 = 6
# 2 X 4 = 8
# 2 X 5 = 10
# 2 X 6 = 12
# 2 X 7 = 14
# 2 X 8 = 16
# 2 X 9 = 18
# 3 단
# 3 X 1 = 3
# 3 X 2 = 6
# 3 X 3 = 9
# 3 X 4 = 12
# 3 X 5 = 15
# 3 X 6 = 18
# 3 X 7 = 21
# 3 X 8 = 24
# 3 X 9 = 27
# 4 단
# 4 X 1 = 4
# 4 X 2 = 8
# 4 X 3 = 12
# 4 X 4 = 16
# 4 X 5 = 20
# 4 X 6 = 24
# 4 X 7 = 28
# 4 X 8 = 32
# 4 X 9 = 36
# 5 단
# 5 X 1 = 5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45
# 6 단
# 6 X 1 = 6
# 6 X 2 = 12
# 6 X 3 = 18
# 6 X 4 = 24
# 6 X 5 = 30
# 6 X 6 = 36
# 6 X 7 = 42
# 6 X 8 = 48
# 6 X 9 = 54
# 7 단
# 7 X 1 = 7
# 7 X 2 = 14
# 7 X 3 = 21
# 7 X 4 = 28
# 7 X 5 = 35
# 7 X 6 = 42
# 7 X 7 = 49
# 7 X 8 = 56
# 7 X 9 = 63
# 8 단
# 8 X 1 = 8
# 8 X 2 = 16
# 8 X 3 = 24
# 8 X 4 = 32
# 8 X 5 = 40
# 8 X 6 = 48
# 8 X 7 = 56
# 8 X 8 = 64
# 8 X 9 = 72
# 9 단
# 9 X 1 = 9
# 9 X 2 = 18
# 9 X 3 = 27
# 9 X 4 = 36
# 9 X 5 = 45
# 9 X 6 = 54
# 9 X 7 = 63
# 9 X 8 = 72
# 9 X 9 = 81

# %% [markdown]
# ### 12. A string is a palindrome if it is identical forward and backward. For example “anna”, “civic”, “level” and “hannah” are all examples of palindromic words. Write a program that reads a string from the user and uses a loop to determines whether or not it is a palindrome. Display the result, including a meaningful output message.
#
# #### (시험문제 예시 : 위와 같은 문제가 2 or 1문제 나올 예정임)

# %%
userInput = input("Enter any string : ")

if userInput == userInput[::-1] :
    print("Palindrome")
else :
    print("Not Palindrome")
# Out:
# Enter any string : chan
# Not Palindrome
